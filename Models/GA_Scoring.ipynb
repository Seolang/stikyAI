# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np

# load model
model = tf.keras.models.load_model("/content/drive/Shareddrives/GP/Final/AR_FL/Stratified_3-fold_CNN_AR_FL_0.h5")

# %%
#onehot_decoder
# (38, 4)로 이루어진 벡터 시퀀스를 문자열 시퀀스로 디코딩 한다.
def onehot_decoder(seq, word=['A','G','C','T']):
    out = ""
    
    for i in range(9, 29):
        arg = np.argmax(seq[i])
        out += word[arg]
    #out+="/"        
    return out

# %%
#Genetic Algorithm

#Initialize
def init():
  pool = []
  for i in range(30):   #유전자풀에 30개의 초기 염기서열을 (38, 4) 크기의 One-Hot Vector로 생성한다.
    seq = []
    for i in range(9):
        seq.append([.25, .25, .25, .25])
    for i in range(20):
        acid = [0, 0, 0, 0]
        n = np.random.randint(0,4)
        acid[n] = 1
        seq.append(acid)
    for i in range(9):
        seq.append([.25, .25, .25, .25])
    pool.append(seq)
  return np.array(pool)
 
#fitness
def fitness(model, pool):   # model = classifier
  scores = [0]*30
  for i in range(30):       # 유전자 풀의 30개의 염기서열을 분류기로 평가하여 그 점수들을 같은 index를 갖는 scores 리스트로 반환한다.  
    seq = np.array(pool[i]).reshape(1,38,4)
    proba = model.predict(seq)
    scores[i] = proba[0][0]
  
  return scores
 
#selection
def selection(pool, scores):
  temp = []
  while len(temp) < 8:  #적합도가 가장 높은 8개의 유전자를 선정
    index = np.argmax(scores)
    if pool[index] not in temp:
      temp.append(pool[index])
    del scores[index]
    del pool[index]
 
  p1 = temp[0][:] #4개의 부모 유전자
  p2 = temp[1][:]
  p3 = temp[2][:]
  p4 = temp[3][:]
  x = np.random.randint(9,29) #교차 위치 선정
  c1 = p1[:x] + p2[x:] #4개의 자식 유전자 생성
  c2 = p2[:x] + p1[x:]
  x = np.random.randint(9,29)
  c3 = p3[:x] + p4[x:]
  c4 = p4[:x] + p3[x:]
  temp.append(c1)
  temp.append(c2)
  temp.append(c3)
  temp.append(c4)
 
  n = np.random.randint(10,16)  #부모 및 자식의 돌연변이 갯수 선정
  for i in range(n):
    index = np.random.randint(0,12)  #오리지날 부모 및 자식 중 하나 선택
    temp_seq = temp[index][:]
    pos_a = np.random.randint(9,29) #돌연변이 시작위치 선정
    pos_b = np.random.randint(pos_a,29) #돌연변이 끝 위치 선정
    for j in range(pos_a, pos_b+1): #pos_a 부터 pos_b까지의 모든 아미노산을 돌연변이 시킴
      temp_acid = [0, 0, 0, 0]
      r = np.random.randint(0,4)  #돌연변이 값 (A,G,T,C 중 하나) 선정
      temp_acid[r] = 1
      temp_seq[j] = temp_acid[:]
 
    temp.append(temp_seq)
 
  for i in range(18-n): #부모와 자식, 돌연변이 외 나머지는 완전 무작위로 sequence를 생성
    seq = []
    for i in range(9):
        seq.append([.25, .25, .25, .25])
    for i in range(20):
        acid = [0, 0, 0, 0]
        n = np.random.randint(0,4)
        acid[n] = 1
        seq.append(acid)
    for i in range(9):
        seq.append([.25, .25, .25, .25])

    temp.append(seq)
 
  return np.array(temp)

# %%
from collections import defaultdict
from tqdm import tqdm

seqs = []
for i in tqdm(range(50)):
  pool = init()
  for j in range(30):
    scores = fitness(model, pool)
    pool = selection(pool.tolist(), scores)[:]
  
  scores = fitness(model, pool)
  for seq, score in zip(pool, scores):
    if score > 0.8:
      most_seq = seq
      decode_seq = onehot_decoder(most_seq)
      seqs.append(decode_seq)
# Out:
# 100%|██████████| 50/50 [33:21<00:00, 40.03s/it]

# %%
for i in (seqs,scores):
    print(i)
# Out:
# ['CCCCGCGGAACACTGTGTTG', 'CCCCGCGGAACACTATGATC', 'CATCCCGGAACAAAGTGATC', 'CATCCCGGAACAAAGTGGCG', 'CATCCCGGAACAAAGTGGCC', 'CATCCCGGAACAAAGTGGCT', 'CATGCGGGAACACTATGACC', 'CATGCGGGAACACTATGATC', 'CCCCGCGGAACACTATGATC', 'CCCCGCGGAACACTGTGTTG', 'CATCCCGGAACAAAGTGGCG', 'CATCCCGGAACAAAGTGATC', 'CATCCCGGAACAAAGTGGCG', 'CATGCGAGAACACTATGACC', 'CTGATCGGAACAAAGTGGCG', 'CATCCCGGAACAAACTGGCG', 'CATCCCGGAACAAAGTCGGC', 'CCCCGCGGAACAATTGGTTG', 'CCCCGCGGAACACTGGGTTG', 'CCGCCGAACACGGTGGAATA', 'CCGCCGAACACGGTGGAATC', 'CCGCCGAACACGGTGGCATG', 'CCGCCGAACACGGTGTTATA', 'CCGCCGAACACGGTGTAATG', 'CCGCCGAACACGGTGGAATG', 'CCGCCGAACACGGTGCTGCC', 'CCGCGGAACACGGTGGAATA', 'CCGCCGAACACGGTGGAATC', 'CCGCCGAACACGGTGGAATA', 'CCGCCGAACACGGTGGCATA', 'CCGCCGAACACGGTGTTATG', 'CCCCTTTCAATCTTGCTGCC', 'CCACCGAACACGGTGTTATA', 'CCGCCGAACACGGTGGAATG', 'CCGCCGAACACGTATCATTC', 'CCGCCGAACCTAGTGGAATG', 'CCGCCGAACACGGTGTTAGG', 'CCGCCGAACACGGTCAAATC', 'CCGCCGAACACGGTCGTATA', 'CCGCCGAACGACAAGTAGTA', 'TCTCACGAACACAGTGATAC', 'TCTCACGAACACAGTGATAT', 'TCTCACGAACACAGTGAAAC', 'TCTCACGAACACAATGATAC', 'TCTCACGAACACAATGAAAC', 'TCTCACGAACACAATGATCC', 'TCTCACGAACACAATGAATC', 'TCTCACGAACACAATGTATC', 'TCTCACGAACACAGTGATAT', 'TCTCACGAACACAGTGATAC', 'TCTCACGAACACAATGATAC', 'TCTCACGAACACAGTGAAAC', 'TCTCACGTAGAACATGATAC', 'TAAGACGGACACAGTGAAAC', 'TCTCACGAACACTATGAAAC', 'TCTCCCGAACACAGTGATAC', 'TCTCACGAACACAATGAATC', 'TCTCACGAACACAGTGATCC', 'TCTCACGAACACAATGCTAC', 'TCTCACGAACACAGTACAGG', 'TCTCACGAACACAGTTATAT', 'TCTCACGAACACAATGCAGA', 'CCTCAAGCCGAACACAGTGA', 'CCGTAAGCCGAACACAGTGA', 'CCCTAATACGAACACAGTGA', 'CCGTAATACGAACACAGTGA', 'CCGTAACCCGAACACAGTGA', 'CCAGAAGCCGAACACAGTGA', 'CATAAAGCCGAACACAGTGA', 'CCGTACGCCGTACACGGTGG', 'CCTCAAGCCGAACACAGTGA', 'CCGTAAGCCGAACACAGTGA', 'CCCTAATACGAACACAGTGA', 'CCGTAATACGAACACAGTGA', 'CCGTCTCACGAACACAGTGA', 'CCTCAAGCCGAATATTGTGA', 'CCCTAATATTAACACAGTGA', 'CCCTAATACGAACACAGTGA', 'CCAAGTTACGAACACAGTGA', 'CCGTAATACGAAAACAGTGA', 'CCGTACGCAGTGCACGGTGG', 'CCCGGTGGAACACTATGTTA', 'CCCGGTGGAACACTATGTTC', 'GCTAGTGGAACACTATGTTA', 'CCCGGCGGTACACTATGTTC', 'CCCGGCGGTACACTATGTTG', 'CCCGGTGGTACACTATGTTC', 'CCCGGTGGTACACTATGTTA', 'CCCGGTGGTACACTATGTAA', 'CCCGGTGGAACACTATGTTC', 'CCCGGTGGAACACTATGTTA', 'GCTAGTGGTACACTATGTTC', 'CCCGGCGGAACACTATGTTA', 'CCCGGCCGTACACTATGTTG', 'CCCAGGGTTACACTATGTTC', 'CCCGGTGGTATAATATGTTC', 'CCCGGTGGAACACTATGTGC', 'CCCGGTGGAACATCCGGTGC', 'CCCGGCGGTACACTATGACG', 'CCCGGCGGAACACTATGATC', 'TCCCCTTGAACGAAATGATA', 'TCCCCTTGAACTAAATGATA', 'TCCCCTTGAACTAAATGAAA', 'TCCTAAAGAACGAAATGATA', 'TCCTACTGAACGAAATGATA', 'TCCCCTTGAACTAAATGAAG', 'TCCCCTTGAATAAAATGATA', 'TCCCCTTGAATAAAATGGTA', 'TCCCCTTGAACTAAATGATA', 'TCCCCTTGAACGAAATGATA', 'TCCCCTTGAACTAAATGATA', 'TCCTAAAGAACGAAATGAAA', 'TCCCCTTGAGAGAAATGATA', 'TCCCCTTGAACTAAATGAAG', 'TCCCCTTGAACTGAATGAAG', 'TCCCCTTGATAGCGGTGATA', 'TCCCCTTGAACTAAATGATA', 'TCCTAAAGAACGAAATGTAG', 'TCCCCTTGAACTAAGTGATA', 'CCCGAACACGGTGCCTTGGC', 'CCCGAACACGGTGTAAAAGG', 'CCCGAACACGGTGTAATGCA', 'CCCGAACACGGTGTCCTCTG', 'CCCGAACACGGTGCCATGGC', 'CCCGAACACGGTGCCATGGG', 'CCCGAACACGGTGCCATCTA', 'CCCGAACACGGTGCCTAAGG', 'CCCGAACACGGTGCAAAAGG', 'CCCGAACACGGTGTCTTGGC', 'CCCGAACACGGTGTCCTCTG', 'CCCGAACACGGTGTAATGCA', 'CCCGAACACTGTTTATGTTC', 'CCCGAACACGGTGTCCCGGG', 'CCCGAACACGGTGCCTAAGG', 'CCCAAACACGGTGCCTAAGG', 'CCCGAACACGGTGTCTTAAC', 'GTCTCGCCTGTACACTGTGG', 'GAGAACATAATGGATCCCTT', 'GAGAACATAATGGATGCCTT', 'GAGAACATAATGGATCCTAT', 'GAGAACAAAATGGATCCCTT', 'GAGAACATAATGGATCCCTA', 'GAGAACATAATGGTTCCCTT', 'GAGAACATAATGGATCGCTT', 'GAGAACATAATGGATCCTTA', 'GAGAACATAATGGATGCCTT', 'GAGAACATAATGGATCCCTT', 'GAGAACATAATGGATCCCTT', 'GAGAACAAAATGGATCCTAT', 'GAGAACATAATGGATCCCGT', 'GAGAACATAATGGATCCGAA', 'GAGAACATAATGGATGCCTT', 'GAGAACATAATGGATCCTAG', 'GAGAACATAATGGGGCACTT', 'CCGTAAGAATACGGTGCTAT', 'CCGTAAGAATACGGTGCTAC', 'CCGTAAGAAAACGGTGCTAT', 'CCGTAAGAAAACGGTGCAAA', 'CCGTAAGAAAACGGTGCTAA', 'CCGTAAGAAAATGGTGCTAA', 'CCGTAAGAAAACGGTGCTTA', 'CCGTAAGAAAACGGTGCTAC', 'CCGTAAGAATACGGTGCTAC', 'CCGTAAGAATACGGTGCTAT', 'CCGTAAGAAAACGGTGCAAA', 'CCGTAAGAAAACGGTGCTAT', 'CCGTAATTAAACGG ...
# [0.9882527, 0.9881733, 0.9879921, 0.9859744, 0.98527884, 0.9851243, 0.98476636, 0.98467964, 0.9881733, 0.9882527, 0.9879921, 0.9859744, 0.89534414, 0.78841066, 0.99179816, 0.93487865, 0.8122685, 0.6209554, 0.80237085, 0.9795857, 0.8088703, 0.98510367, 0.9872591, 0.9534561, 0.64285356, 0.6724457, 0.8766649, 0.5662298, 0.6341449, 0.61578035]

# %%
f = open("/content/drive/Shareddrives/GP/Final/Result Seq/DeepBind_AR_FL.txt", 'w')
for seq in seqs:
  f.write(f'{seq}\n')
f.close()
